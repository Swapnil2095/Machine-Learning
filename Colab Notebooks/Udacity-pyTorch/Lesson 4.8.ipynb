# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/"
# Out:
# 'Udacity L4.8.ipynb'   Udacity-pyTorch

# %%
# !pip install -q torch

# %%
# !pip install -q torchvision

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (5.3.0)

# %%
#%cd /content/drive/My Drive/Colab Notebooks/`
#!`git clone https://github.com/Swapnil2095/deep-learning-v2-pytorch.git
ls
# Out:
# drive/  sample_data/

# %%
# Out:
# Cloning into 'deep-learning-v2-pytorch'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 710 (delta 4), reused 11 (delta 3), pack-reused 695
# Receiving objects: 100% (710/710), 126.14 MiB | 23.65 MiB/s, done.
# Resolving deltas: 100% (239/239), done.
# Checking out files: 100% (270/270), done.

# %%
cd drive/My Drive/Colab Notebooks
# Out:
# /content/drive

# %%
ls
# Out:
# 'My Drive'/

# %%
# Out:
# /content/drive/My Drive

# %%
# !git clone https://github.com/Swapnil2095/deep-learning-v2-pytorch.git
# Out:
# Cloning into 'deep-learning-v2-pytorch'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 710 (delta 4), reused 11 (delta 3), pack-reused 695
# Receiving objects: 100% (710/710), 126.14 MiB | 13.56 MiB/s, done.
# Resolving deltas: 100% (239/239), done.
# Checking out files: 100% (270/270), done.

# %%
ls
# Out:
#  deep-learning-v2-pytorch/  'Udacity L4.8.ipynb'   Udacity-pyTorch/

# %%
cd
